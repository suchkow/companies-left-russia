# %% [markdown]
# # Cleaning. Version 1

# %%
# %run parsing.ipynb import comp_df, regs_df, regs_abb_df

# regs_df - quite clear df, as well as regs_abb_df
# there is question about comp_df

# %%
comp_df
# Out:
#                      Name                                             Action  \
# 0                Aalberts  continue operations on an unspecified "lower" ...
# 1     Abbott Laboratories            suspend non-essential business activity
# 2                  Abbvie  suspend aesthetics operations, pause new clini...
# 3                   Accor                suspend new investments/development
# 4               Accumalux         still operating plant in Togliatti, Russia
# ...                   ...                                                ...
# 2018           HMD Global                    приняла решение уйти с рынка РФ
# 2019               Heroku  Облачная PaaS-платформа Heroku больше не регис...
# 2020            Parallels  Компания по разработке программного обеспечени...
# 2021             Qt Group      ограничил доступ для российских пользователей
# 2022               Deeper                 приостановил деятельность в России
#
#                     Industry        Country         ИНН
# 0                Industrials    Netherlands         NaN
# 1                Health Care  United States  7725594604
# 2                Health Care  United States  7743855873
# 3     Consumer Discretionary         France  7704662187
# 4     Consumer Discretionary     Luxembourg  6321413868
# ...                      ...            ...         ...
# 2018  Information Technology      Финляндия  7704376115
# 2019  Information Technology            США         NaN
# 2020  Information Technology            США  5406309261
# 2021  Information Technology       Норвегия         NaN
# 2022  Information Technology          Литва  4909105167
#
# [2023 rows x 5 columns]

# %%
comp_df.pop('Action')
# Out:
# 0       continue operations on an unspecified "lower" ...
# 1                 suspend non-essential business activity
# 2       suspend aesthetics operations, pause new clini...
# 3                     suspend new investments/development
# 4              still operating plant in Togliatti, Russia
#                               ...
# 2018                      приняла решение уйти с рынка РФ
# 2019    Облачная PaaS-платформа Heroku больше не регис...
# 2020    Компания по разработке программного обеспечени...
# 2021        ограничил доступ для российских пользователей
# 2022                   приостановил деятельность в России
# Name: Action, Length: 2023, dtype: object

# %%
comp_df[1152:1210]
# Out:
#                         Name                Industry         Country  \
# 1152  Zurich Insurance Group              Financials     Switzerland
# 1153                     NaN                     NaN             NaN
# 1154              McDonald’s        Consumer Staples             NaN
# 1155             Yum! Brands        Consumer Staples             NaN
# 1156        Lindt & Sprüngli        Consumer Staples             NaN
# 1157                 Lavazza        Consumer Staples             NaN
# 1158             Intel и AMD  Information Technology             NaN
# 1159                  Twitch  Information Technology             NaN
# 1160                OnlyFans  Information Technology             NaN
# 1161            Vista Create  Information Technology             NaN
# 1162                  Pexels  Information Technology             NaN
# 1163                 Pixabay  Information Technology             NaN
# 1164              Google Pay  Information Technology             NaN
# 1165               Apple Pay  Information Technology             NaN
# 1166                   Figma  Information Technology             NaN
# 1167                  PayPal              Financials             NaN
# 1168                 Moody’s              Financials             NaN
# 1169         JP Morgan Chase              Financials             NaN
# 1170                Mubadala              Financials             NaN
# 1171               Saxo Bank              Financials             NaN
# 1172               Bloomberg              Financials             NaN
# 1173                    ASUS             Industrials             NaN
# 1174                  Suzuki             Industrials             NaN
# 1175             Rolls-Royce             Industrials             NaN
# 1176        Volkswagen Group             Industrials             NaN
# 1177          General Motors             Industrials             NaN
# 1178             Lamborghini             Industrials             NaN
# 1179                Infiniti             Industrials             NaN
# 1180                 Cartier        Consumer Staples             NaN
# 1181                Reserved        Consumer Staples             NaN
# 1182                    Lush             Health Care             NaN
# 1183                   iHerb             Health Care             NaN
# 1184                 Watsons             Health Care             NaN
# 1185              L’Occitane        Consumer Staples             NaN
# 1186                    IKEA        Consumer Staples             NaN
# 1187                  Megogo  Consumer Discretionary             NaN
# 1188      Universal Pictures  Consumer Discretionary             NaN
# 1189             Walt Disney  Consumer Discretionary             NaN
# 1190           Sony Pictures  Consumer Discretionary             NaN
# 1191                   Globo             Industrials             NaN
# 1192                   Ampol             Industrials             NaN
# 1193             Viva Energy             Industrials             NaN
# 1194     Procter & Gamble Co             Health Care             NaN
# 1195                 Nurofen             Health Care             NaN
# 1196               Strepsils             Health Care             NaN
# 1197             Cillit Bang             Health Care             NaN
# 1198                  Vanish             Health Care             NaN
# 1199                   Durex             Health Care             NaN
# 1200                   Volvo             Industrials             NaN
# 1201                 Peugeot             Industrials             NaN
# 1202                 PepsiCo        Consumer Staples             NaN
# 1203  Mondelez International        Consumer Staples             NaN
# 1204               Cитимобил  Consumer Discretionary             NaN
# 1205             Samsung Pay  Information Technology             NaN
# 1206                 Adsense  Communication Services             США
# 1207                 DMarket              Financials             США
# 1208               BTC-Alpha              Financials  Великобритания
# 1209                   QMall              Financials         Украина
#
#              ИНН
# 1152  7707062854
# 1153  7707062854
# 1154  7710044140
# 1155         NaN
# 1156         NaN
# 1157  7727553628
# 1158         NaN
# 1159         NaN
# 1160         NaN
# 1161         NaN
# 1162         NaN
# 1163         NaN
# 1164         NaN
# 1165         NaN
# 1166  9731051832
# 1167  7750005796
# 1168  7714594218
# 1169  7740000076
# 1170  7017126251
# 1171         NaN
# 1172  7704233195
# 1173  7702402151
# 1174  7704558059
# 1175  7728849515
# 1176  7702349370
# 1177  5402059557
# 1178         NaN
# 1179  7715847006
# 1180  7714469048
# 1181  1514018103
# 1182  7714229906
# 1183  9710079940
# 1184         NaN
# 1185  7707591760
# 1186  5047076050
# 1187  7703769593
# 1188  7703693915
# 1189  7710608533
# 1190  7710744977
# 1191  7728112810
# 1192  3906016728
# 1193         NaN
# 1194  7701032910
# 1195         NaN
# 1196  6671278333
# 1197         NaN
# 1198  9710040822
# 1199         NaN
# 1200  5047105054
# 1201  7701534807
# 1202  7705034202
# 1203  7707778655
# 1204  7724365672
# 1205         NaN
# 1206         NaN
# 1207         NaN
# 1208         NaN
# 1209         NaN

# %%
import re

def has_cyrillic(text):
    return bool(re.search('[\u0400-\u04FF]', text))

# %%
print('Number of all countries:', len(comp_df['Country'].tolist()))
print('Number of unique countries:', len(comp_df['Country'].unique().tolist()))
# Out:
# Number of all countries: 2023
# Number of unique countries: 107

# %%
comp_df['Country'].unique().tolist()
# Out:
# ['Netherlands',
#  'United States',
#  'France',
#  'Luxembourg',
#  'Slovenia',
#  'Switzerland',
#  'Andorra',
#  'Austria',
#  'Spain',
#  'United Kingdom',
#  'Germany',
#  'Finland',
#  'Italy',
#  'China',
#  'Estonia',
#  'Canada',
#  'Poland',
#  'Portugal',
#  'Latvia',
#  'Belgium',
#  'Denmark',
#  'Australia',
#  'Japan',
#  'Mexico',
#  'Cyprus',
#  'Greece',
#  'Czech Republic',
#  'Hong Kong',
#  'Iceland',
#  'India',
#  'Singapore',
#  'Bermuda',
#  'Liechtenstein',
#  'Lithuania',
#  'Slovakia',
#  'United Arab Emirates',
#  'Norway',
#  'Hungary',
#  'Israel',
#  'Sweden',
#  'Taiwan',
#  'Kazakhstan',
#  'Malta',
#  'Azerbaijan',
#  'Malaysia',
#  'Romania',
#  'Bulgaria',
#  'Ukraine',
#  'Brazil',
#  'South Korea',
#  'Ireland',
#  'Monaco',
#  'Croatia',
#  'Sri Lanka',
#  'Vietnam',
#  'New Zealand',
#  'South Africa',
#  'Belarus',
#  'Panama',
#  nan,
#  'США',
#  'Великобритания',
#  'Украина',
#  'США, Великобритания',
#  'Испания',
#  'Италия',
#  'Япония',
#  'Германия',
#  'Нидерланды',
#  'Франция',
#  'Венгрия',
#  'Польша',
#  'Норвегия',
#  'Сингапур',
#  'Швейцария',
#  'Малайзия',
#  'Швеция',
#  'Австралия',
#  'Ирландия',
#  'Кипр',
#  'Россия',
#  'Южная Корея',
#  'Тайвань',
#  'Канада',
#  'Дания',
#  'Финляндия',
#  'Эстония',
#  'Люксембург',
#  'Каймановы острова',
#  'Латвия',
#  'Мальта',
#  'Чехия',
#  'Worldwide',
#  'Литва',
#  'Болгария',
#  'Корея',
#  'Ангилья',
#  'Новая Зеландия',
#  'Словакия',
#  'Европейский союз',
#  'Израиль',
#  'Индия',
#  'Китай',
#  'Гонконг',
#  'Беларусь',
#  'Молдова',
#  'Швеция, Швейцария']

# %%
comp_df[comp_df['Country'] == 'Швеция, Швейцария']
# Out:
#      Name     Industry            Country         ИНН
# 2015  АВВ  Industrials  Швеция, Швейцария  5837009706

# %%
print(comp_df.isnull().sum())
print('Overall\t', comp_df.isnull().sum().sum())
# Out:
# Name          1
# Industry    548
# Country     238
# ИНН         849
# dtype: int64
# Overall	 1636

# %%
clear_comp_df = comp_df.dropna(axis=0, thresh=3)
comp_df.style.highlight_null(color='yellow')
# Out:
# <style type="text/css">
# #T_370ba_row0_col3, #T_370ba_row5_col3, #T_370ba_row8_col3, #T_370ba_row10_col3, #T_370ba_row11_col3, #T_370ba_row17_col3, #T_370ba_row22_col3, #T_370ba_row23_col3, #T_370ba_row30_col3, #T_370ba_row32_col3, #T_370ba_row33_col3, #T_370ba_row35_col3, #T_370ba_row36_col3, #T_370ba_row41_col3, #T_370ba_row45_col3, #T_370ba_row51_col3, #T_370ba_row53_col3, #T_370ba_row55_col3, #T_370ba_row58_col3, #T_370ba_row62_col3, #T_370ba_row63_col3, #T_370ba_row66_col3, #T_370ba_row69_col3, #T_370ba_row78_col3, #T_370ba_row85_col3, #T_370ba_row88_col3, #T_370ba_row91_col3, #T_370ba_row92_col3, #T_370ba_row93_col3, #T_370ba_row95_col3, #T_370ba_row96_col3, #T_370ba_row101_col3, #T_370ba_row104_col3, #T_370ba_row105_col3, #T_370ba_row106_col3, #T_370ba_row108_col3, #T_370ba_row116_col3, #T_370ba_row136_col3, #T_370ba_row143_col3, #T_370ba_row147_col3, #T_370ba_row153_col3, #T_370ba_row159_col3, #T_370ba_row162_col3, #T_370ba_row166_col3, #T_370ba_row174_col3, #T_370ba_row180_col3, #T_370ba_row185_col3, #T_370ba_row190_col3, #T_370ba_row194_col3, #T_370ba_row195_col3, #T_370ba_row202_col3, #T_370ba_row206_col3, #T_370ba_row216_col3, #T_370ba_row218_col3, #T_370ba_row219_col3, #T_370ba_row220_col3, #T_370ba_row225_col3, #T_370ba_row227_col3, #T_370ba_row228_col3, #T_370ba_row231_col3, #T_370ba_row234_col3, #T_370ba_row237_col3, #T_370ba_row238_col3, #T_370ba_row247_col3, #T_370ba_row248_col3, #T_370ba_row253_col3, #T_370ba_row259_col3, #T_370ba_row260_col3, #T_370ba_row263_col3, #T_370ba_row264_col3, #T_370ba_row265_col3, #T_370ba_row267_col3, #T_370ba_row269_col3, #T_370ba_row270_col3, #T_370ba_row277_col3, #T_370ba_row278_col3, #T_370ba_row280_col3, #T_370ba_row283_col3, #T_370ba_row286_col3, #T_370ba_row287_col3, #T_370ba_row291_col3, #T_370ba_row292_col3, #T_370ba_row297_col3, #T_370ba_row298_col3, #T_370ba_row300_col3, #T_370ba_row303_col3, #T_370ba_row307_col1, #T_370ba_row315_col3, #T_370ba_row324_col3, #T_370ba_row326_col3, #T_370ba_row330_col3, #T_370ba_row335_col3, #T_370ba_row338_col3, #T_370ba_row342_col3, #T_370ba_row343_col3, #T_370ba_row348_col3, #T_370ba_row349_col3, #T_370ba_row350_col3, #T_370ba_row351_col3, #T_370ba_row356_col3, #T_370ba_row359_col3, #T_370ba_row365_col3, #T_370ba_row369_col3, #T_370ba_row371_col3, #T_370ba_row375_col3, #T_370ba_row377_col3, #T_370ba_row378_col3, #T_370ba_row382_col3, #T_370ba_row383_col3, #T_370ba_row385_col3, #T_370ba_row388_col3, #T_370ba_row393_col3, #T_370ba_row394_col3, #T_370ba_row401_col3, #T_370ba_row403_col3, #T_370ba_row406_col3, #T_370ba_row407_col3, #T_370ba_row410_col3, #T_370ba_row412_col3, #T_370ba_row415_col3, #T_370ba_row416_col3, #T_370ba_row417_col3, #T_370ba_row418_col3, #T_370ba_row426_col3, #T_370ba_row430_col3, #T_370ba_row431_col3, #T_370ba_row435_col3, #T_370ba_row439_col3, #T_370ba_row442_col3, #T_370ba_row444_col3, #T_370ba_row448_col3, #T_370ba_row452_col3, #T_370ba_row457_col3, #T_370ba_row458_col3, #T_370ba_row459_col3, #T_370ba_row460_col3, #T_370ba_row462_col3, #T_370ba_row471_col3, #T_370ba_row475_col3, #T_370ba_row477_col3, #T_370ba_row482_col3, #T_370ba_row483_col3, #T_370ba_row496_col3, #T_370ba_row500_col3, #T_370ba_row509_col3, #T_370ba_row511_col3, #T_370ba_row512_col3, #T_370ba_row516_col3, #T_370ba_row520_col3, #T_370ba_row524_col3, #T_370ba_row527_col3, #T_370ba_row529_col3, #T_370ba_row531_col3, #T_370ba_row538_col3, #T_370ba_row540_col3, #T_370ba_row544_col3, #T_370ba_row553_col3, #T_370ba_row554_col3, #T_370ba_row558_col3, #T_370ba_row559_col3, #T_370ba_row560_col3, #T_370ba_row562_col3, #T_370ba_row563_col3, #T_370ba_row566_col3, #T_370ba_row570_col3, #T_370ba_row574_col3, #T_370ba_row575_col3, #T_370ba_row576_col3, #T_370ba_row589_col3, #T_370ba_row590_col3, #T_370ba_row592_col3, #T_370ba_row595_col3, #T_370ba_row600_col3, #T_370ba_row602_col3, #T_370ba_row604_col3, #T_370ba_row609_col3, #T_370ba_row610_col3, #T_370ba_row611_col3, #T_370ba_row623_col3, #T_370ba_row624_col3, #T_370ba_row625_col3, #T_370ba_row633_col3, #T_370ba_row641_col3, #T_370ba ...

# %%
clear_comp_df[1375:1522]['Name']
# Out:
# 1408               KIA
# 1409            Jaguar
# 1410        Land Rover
# 1412       MacDonald’s
# 1413               KFC
#              ...
# 1920    Siemens Energy
# 1921      Trimble Inc.
# 1922             Maxon
# 1923               TNT
# 1925           Junttan
# Name: Name, Length: 147, dtype: object
